# %% [markdown]
# # EXTRACCIÓN DE DATOS CON SELENIUM #
#
# En este proyecto, se utilizará lenguaje pyhton junto con librería Selenium para realizar web scraping en una página web que contiene información sobre tiburones. El objetivo es extraer los datos correspondientes a las siguientes categorías: Nombre_cientifico, Familia, Genero, Status_IUCN, Tamaño_medio, Descriptor, Año y Sociabilidad, limpiarlos y almacenarlos en una base de datos MySQL para realizar consultas posteriores.
#
# - Proceso:
#
# -Configuración del entorno en Visual Studio Code (VSC):
# Para comenzar, se instalarán las herramientas necesarias, como Selenium WebDriver y el controlador de un navegador ChromeDriver. Esto permitirá automatizar la interacción con la página web desde VSC.
#
# -Extracción de datos con Selenium:
# Utilizando el WebDriver de Selenium, accederemos a la página web que contiene datos de tiburones. Se recorrerán las páginas de cada tiburón, extrayendo los valores correspondientes a cada columna construido gracias a bucles try y for.
#
# -Limpieza de datos:
# En particular, el Tamaño medio viene acompañado de la unidad de medida en centímetros (por ejemplo, "200 cm"). Para poder utilizar estos valores en cálculos numéricos, se procederá a eliminar esta unidad de medida y convertir el valor a un número entero que se pueda almacenar y procesar sin dificultades.
#
# -Creación de un DataFrame :
# Se convierte nuestra extracción de datos, a lista para poder asociarlo con MySQL. Esto permitirá organizar la información de forma estructurada antes de ser almacenada en la base de datos.
#
# -Conexión a MySQL y almacenamiento de datos:
# Finalmente, se establecerá una conexión con una base de datos MySQL, creando una tabla adecuada para almacenar la información de los tiburones. Los datos extraídos (limpios y organizados) se insertarán en dicha tabla, lo que permitirá realizar consultas más adelante, como obtener estadísticas, filtrar especies por características específicas, etc.
#
# Este proyecto combina automatización web, procesamiento de datos y almacenamiento en bases de datos, ofreciendo una solución completa para la recopilación y análisis de información sobre tiburones desde la web.
#
# A continuación los pasos:

# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
# Iniciar el navegador
driver = webdriver.Chrome()
driver.maximize_window()

# Acceder a la web
driver.get("https://www.fishipedia.es/pez/type/requin")
print("Accede a la web")

lista_tiburones = [] # Aquí creamos una lista vacía, donde se irán adjuntando los datos

# Hacemos un scrapeo para 32 filas:

for i in range(1,32):
    # Hacer clic en cada tiburón
    driver.find_element("css selector", f"#listItems > li:nth-child({i}) > div > a").click()
    print(f"Accediendo al tiburón {i}")


    sleep(3)  # Espera para asegurar que la página haya cargado correctamente

    try:
        # Obtener el nombre científico
        nombre_cientifico = driver.find_element("css selector", "#Js--BannerJs table tbody tr.g-6-col td em").text
        print(f"Nombre científico: {nombre_cientifico}")
        familia=driver.find_element("css selector", "#Js--BannerJs > table > tbody > tr:nth-child(5) > td > a").text
        print(f"Familia: {familia}")
        genero=driver.find_element("css selector", "#Js--BannerJs > table > tbody > tr:nth-child(6) > td").text
        print(f"Genero: {genero}")
        descriptor =driver.find_element("css selector", "#Js--BannerJs > table > tbody > tr:nth-child(2) > td").text
        print(f"Descriptor: {descriptor}")
        anio =driver.find_element("css selector", "#Js--BannerJs > table > tbody > tr:nth-child(3) > td").text
        print(f"Año: {anio}")
        IUCN_status =driver.find_element("css selector", "#Js--BannerJs > table > tbody > tr:nth-child(4) > td").text
        print(f"Status_IUCN: {IUCN_status}")
        try:
            tamano_medio=driver.find_element("css selector", "#sheetContent > section:nth-child(3) > div:nth-child(3) > div.isHiddenBeforeExLarge > ul > li.g-6-col.g-d-3-col.g-l-12-col.g-cell.inColumnDesk.ListHighlightInfo--Icon.ListHighlightInfo--Icon-size > div.ListHighlightInfo--Value.isCapitalize").text
            print(f"Tamaño medio: {tamano_medio}")
        except:
            print("sin dato")
        try:
            social=driver.find_element("css selector", "#sheetContent > section:nth-child(3) > div:nth-child(7) > ul > li.g-12-col.g-t-6-col.g-l-3-col.g-cell.ListHighlightInfo--Icon.ListHighlightInfo--Icon-sociability > div.ListHighlightInfo--Value.isCapitalize").text
            print(f"Sociabilidad: {social}")
        except:
            print("sin dato")
      
        # Guardar en la lista
        lista_tiburones.append({"Nombre_cientifico": nombre_cientifico, "Familia": familia,
                                "Genero":genero ,"Status_IUCN":IUCN_status,
                                "Tamaño_medio" :tamano_medio, "Descriptor":descriptor, "Año": anio,
                                "Sociabilidad":social})
        
    except Exception as e:
        print(f"Error al obtener el dato {i}: {e}")

    sleep(2)  # Pequeña pausa antes de regresar
    driver.back()
    sleep(3)  # Espera a que la lista de tiburones se vuelva a cargar

# Cerrar el navegador
driver.quit()

# Imprimir resultados
print("Lista de tiburones:", lista_tiburones)
# Out:
# Accede a la web
# Accediendo al tiburón 1
# Nombre científico: Alopias pelagicus
# Familia: alopiidae
# Genero: Alopias
# Descriptor: Nakamura
# Año: 1935
# Status_IUCN: EN
# Tamaño medio: 276 cm
# Sociabilidad: solitario
# Accediendo al tiburón 2
# Nombre científico: Atelomycterus marmoratus
# Familia: Scyliorhinidae
# Genero: Atelomycterus
# Descriptor: Bennet
# Año: 1830
# Status_IUCN: NT
# Tamaño medio: 55 cm
# sin dato
# Accediendo al tiburón 3
# Nombre científico: Carcharhinus amblyrhynchos
# Familia: Carcharhinidae
# Genero: Carcharhinus
# Descriptor: Bleeker
# Año: 1856
# Status_IUCN: EN
# Tamaño medio: 170 cm
# sin dato
# Accediendo al tiburón 4
# Nombre científico: Carcharhinus falciformis
# Familia: Carcharhinidae
# Genero: Carcharhinus
# Descriptor: Müller & Henle
# Año: 1839
# Status_IUCN: VU
# Tamaño medio: 200 cm
# sin dato
# Accediendo al tiburón 5
# Nombre científico: Carcharhinus leucas
# Familia: Carcharhinidae
# Genero: Carcharhinus
# Descriptor: Müller & Henle
# Año: 1839
# Status_IUCN: VU
# Tamaño medio: 190 cm
# sin dato
# Accediendo al tiburón 6
# Nombre científico: Carcharhinus melanopterus
# Familia: Carcharhinidae
# Genero: Carcharhinus
# Descriptor: Quoy & Gaimard
# Año: 1824
# Status_IUCN: VU
# Tamaño medio: 100 cm
# sin dato
# Accediendo al tiburón 7
# Nombre científico: carcharhinus plumbeus
# Familia: Carcharhinidae
# Genero: Carcharhinus
# Descriptor: Nardo
# Año: 1827
# Status_IUCN: EN
# Tamaño medio: 200 cm
# sin dato
# Accediendo al tiburón 8
# Nombre científico: Carcharias taurus
# Familia: Carcharhinidae
# Genero: Carcharias
# Descriptor: Rafinesque
# Año: 1810
# Status_IUCN: CR
# Tamaño medio: 220 cm
# sin dato
# Accediendo al tiburón 9
# Nombre científico: Carcharodon carcharias
# Familia: Lamnidae
# Genero: Carcharodon
# Descriptor: Carl von Linné
# Año: 1758
# Status_IUCN: VU
# Tamaño medio: 450 cm
# Sociabilidad: solitario
# Accediendo al tiburón 10
# Nombre científico: Cetorhinus maximus
# Familia: Cetorhinidae
# Genero: Cetorhinus
# Descriptor: Johan Ernst Gunnerus
# Año: 1765
# Status_IUCN: EN
# Tamaño medio: 1000 cm
# Sociabilidad: grupos o en solitario
# Accediendo al tiburón 11
# Nombre científico: Chiloscyllium griseum
# Familia: Hemiscylliidae
# Genero: Chiloscyllium
# Descriptor: Müller & Henle
# Año: 1838
# Status_IUCN: VU
# Tamaño medio: 70 cm
# Sociabilidad: solitario
# Accediendo al tiburón 12
# Nombre científico: Chiloscyllium punctatum
# Familia: Hemiscylliidae
# Genero: Chiloscyllium
# Descriptor: Müller & Henle
# Año: 1838
# Status_IUCN: NT
# Tamaño medio: 120 cm
# sin dato
# Accediendo al tiburón 13
# Nombre científico: Galeocerdo cuvier
# Familia: Carcharhinidae
# Genero: Galeocerdo
# Descriptor: Péron & Le Sueur
# Año: 1822
# Status_IUCN: NT
# Tamaño medio: 300 cm
# sin dato
# Accediendo al tiburón 14
# Nombre científico: Ginglymostoma cirratum
# Familia: Ginglymostomatidae
# Genero: Ginglymostoma
# Descriptor: Bonnaterre
# Año: 1788
# Status_IUCN: VU
# Tamaño medio: 240 cm
# sin dato
# Accediendo al tiburón 15
# Nombre científico: Hemiscyllium Ocellatum
# Familia: Hemiscylliidae
# Genero: Hemiscyllium
# Descriptor: Bonnaterre
# Año: 1788
# Status_IUCN: LC
# Tamaño medio: 90 cm
# Sociabilidad: solitario
# Accediendo al tiburón 16
# Nombre científico: Isurus oxyrinchus
# Familia: Lamnidae
# Genero: Isurus
# Descriptor: Rafinesque
# Año: 1810
# Status_IUCN: EN
# Tamaño medio: 270 cm
# sin dato
# Accediendo al tiburón 17
# Nombre científico: Mustelus mosis
# Familia: Triakidae
# Genero: Mustelus
# Descriptor: Hemprich & Ehrenberg
# Año: 1899
# Status_IUCN: NT
# Tamaño medio: 100 cm
# Sociabilidad: solitario
# Accediendo al tiburón 18
# Nombre científico: Mustelus mustelus
# Familia: Triakidae
# Genero: Mustelus
# Descriptor: Linnaeus
# Año: 1758
# Status_IUCN: EN
# Tamaño medio: 100 cm
# sin dato
# Accediendo al tiburón 19
# Nombre científico: Negaprion brevirostris
# Familia: Carcharhinidae
# Genero: Negaprion
# Descriptor: Poey
# Año: 1868
# Status_IUCN: VU
# Tamaño medio: 240 cm
# Sociabilidad: pequeños grupos
# Accediendo al tiburón 20
# Nombre científico: Orectolobus hutchinsi
# Familia: Orectolobidae
# Genero: Orectolobus
# Descriptor: Last, Chidlow & Compagno
# Año: 2006
# Status_IUCN: LC
# sin dato
# Sociabilidad: solitario
# Accediendo al tiburón 21
# Nombre científico: Poroderma africanum
# Familia: Scyliorhinidae
# Genero: Poroderma
# Descriptor: Gmelin
# Año: 1789
# Status_IUCN: LC
# Tamaño medio: 93 cm
# sin dato
# Accediendo al tiburón 22
# Nombre científico: Prionace glauca
# Familia: Carcharhinidae
# Genero: Prionace
# Descriptor: Linnaeus
# Año: 1758
# Status_IUCN: NT
# Tamaño medio: 335 cm
# sin dato
# Accediendo al tiburón 23
# Nombre científico: Pseudoginglymostoma brevicaudatum
# Familia: Ginglymostomatidae
# Genero: Pseudoginglymostoma
# Descriptor: Günther
# Año: 1867
# Status_IUCN: CR
# Tamaño medio: 60 cm
# Sociabilidad: solitario
# Accediendo al tiburón 24
# Nombre científico: Rhincodon typus
# Familia: Rhincodontidae
# Genero: Rhincodon
# Descriptor: Smith
# Año: 1828
# Status_IUCN: EN
# Tamaño medio: 1000 cm
# Sociabilidad: grupos o en solitario
# Accediendo al tiburón 25
# Nombre científico: Scyliorhinus canicula
# Familia: Scyliorhinidae
# Genero: Scyliorhinus
# Descriptor: Linnaeus
# Año: 1758
# Status_IUCN: LC
# Tamaño medio: 60 cm
# sin dato
# Accediendo al tiburón 26
# Nombre científico: Scyliorhinus stellaris
# Familia: Scyliorhinidae
# Genero: Scyliorhinus
# Descriptor: Linnaeus
# Año: 1758
# Status_IUCN: VU
# Tamaño medio: 100 cm
# sin dato
# Accediendo al tiburón 27
# Nombre científico: Sphyrna lewini
# Familia: Carcharhinidae
# Genero: Sphyrna
# Descriptor: Griffith & Smith
# Año: 1834
# Status_IUCN: CR
# Tamaño medio: 300 cm
# sin dato
# Accediendo al tiburón 28
# Nombre científico: Sphyrna mokarran
# Familia: Carcharhinidae
# Genero: Sphyrna
# Descriptor: Rüppell
# Año: 1837
# Status_IUCN: CR
# Tamaño medio: 300 cm
# sin dato
# Accediendo al tiburón 29
# Nombre científico: Squatina albipunctata
# Familia: Squatinidae
# Genero: Squatina
# Descriptor: Last &White
# Año: 2008
# Status_IUCN: VU
# Tamaño medio: 100 cm
# sin dato
# Accediendo al tiburón 30
# Nombre científico: Squatina squatina
# Familia: Squatinidae
# Genero: Squatina
# Descriptor: Linnaeus
# Año: 1758
# Status_IUCN: CR
# Tamaño medio: 150 cm
# sin dato
# Accediendo al tiburón 31
# Nombre científico: Stegostoma tigrinum
# Familia: Stegostomatidae
# Genero: Stegostoma
# Descriptor: Forster
# Año: 1781
# Status_IUCN: EN
# Tamaño medio: 250 cm
# sin dato
# Lista de tiburones: [{'Nombre_cientifico': 'Alopias pelagicus', 'Familia': 'alopiidae', 'Genero': 'Alopias', 'Status_IUCN': 'EN', 'Tamaño_medio': '276 cm', 'Descriptor': 'Nakamura', 'Año': '1935', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Atelomycterus marmoratus', 'Familia': 'Scyliorhinidae', 'Genero': 'Atelomycterus', 'Status_IUCN': 'NT', 'Tamaño_medio': '55 cm', 'Descriptor': 'Bennet', 'Año': '1830', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Carcharhinus amblyrhynchos', 'Familia': 'Carcharhinidae', 'Genero': 'Carcharhinus', 'Status_IUCN': 'EN', 'Tamaño_medio': '170 cm', 'Descriptor': 'Bleeker', 'Año': '1856', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Carcharhinus falciformis', 'Familia': 'Carcharhinidae', 'Genero': 'Carcharhinus', 'Status_IUCN': 'VU', 'Tamaño_medio': '200 cm', 'Descriptor': 'Müller & Henle', 'Año': '1839', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Carcharhinus leucas', 'Familia': 'Carcharhinidae', 'Genero': 'Carcharhinus', 'Status_IUCN': 'VU', 'Tamaño_medio': '190 cm', 'Descriptor': 'Müller & Henle', 'Año': '1839', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Carcharhinus melanopterus', 'Familia': 'Carcharhinidae', 'Genero': 'Carcharhinus', 'Status_IUCN': 'VU', 'Tamaño_medio': '100 cm', 'Descriptor': 'Quoy & Gaimard', 'Año': '1824', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'carcharhinus plumbeus', 'Familia': 'Carcharhinidae', 'Genero': 'Carcharhinus', 'Status_IUCN': 'EN', 'Tamaño_medio': '200 cm', 'Descriptor': 'Nardo', 'Año': '1827', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Carcharias taurus', 'Familia': 'Carcharhinidae', 'Genero': 'Carcharias', 'Status_IUCN': 'CR', 'Tamaño_medio': '220 cm', 'Descriptor': 'Rafinesque', 'Año': '1810', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Carcharodon carcharias', 'Familia': 'Lamnidae', 'Genero': 'Carcharodon', 'Status_IUCN': 'VU', 'Tamaño_medio': '450 cm', 'Descriptor': 'Carl von Linné', 'Año': '1758', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Cetorhinus maximus', 'Familia': 'Cetorhinidae', 'Genero': 'Cetorhinus', 'Status_IUCN': 'EN', 'Tamaño_medio': '1000 cm', 'Descriptor': 'Johan Ernst Gunnerus', 'Año': '1765', 'Sociabilidad': 'grupos o en solitario'}, {'Nombre_cientifico': 'Chiloscyllium griseum', 'Familia': 'Hemiscylliidae', 'Genero': 'Chiloscyllium', 'Status_IUCN': 'VU', 'Tamaño_medio': '70 cm', 'Descriptor': 'Müller & Henle', 'Año': '1838', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Chiloscyllium punctatum', 'Familia': 'Hemiscylliidae', 'Genero': 'Chiloscyllium', 'Status_IUCN': 'NT', 'Tamaño_medio': '120 cm', 'Descriptor': 'Müller & Henle', 'Año': '1838', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Galeocerdo cuvier', 'Familia': 'Carcharhinidae', 'Genero': 'Galeocerdo', 'Status_IUCN': 'NT', 'Tamaño_medio': '300 cm', 'Descriptor': 'Péron & Le Sueur', 'Año': '1822', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Ginglymostoma cirratum', 'Familia': 'Ginglymostomatidae', 'Genero': 'Ginglymostoma', 'Status_IUCN': 'VU', 'Tamaño_medio': '240 cm', 'Descriptor': 'Bonnaterre', 'Año': '1788', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Hemiscyllium Ocellatum', 'Familia': 'Hemiscylliidae', 'Genero': 'Hemiscyllium', 'Status_IUCN': 'LC', 'Tamaño_medio': '90 cm', 'Descriptor': 'Bonnaterre', 'Año': '1788', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Isurus oxyrinchus', 'Familia': 'Lamnidae', 'Genero': 'Isurus', 'Status_IUCN': 'EN', 'Tamaño_medio': '270 cm', 'Descriptor': 'Rafinesque', 'Año': '1810', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Mustelus mosis', 'Familia': 'Triakidae', 'Genero': 'Mustelus', 'Status_IUCN': 'NT', 'Tamaño_medio': '100 cm', 'Descriptor': 'Hemprich & Ehrenberg', 'Año': '1899', 'Sociabilidad': 'solitario'}, {'Nombre_cientifico': 'Mustelus mustelus', 'Familia': 'Triakidae', 'Genero': 'Mustelus', 'Status_IUCN': 'EN', 'Tamaño_medio': '100 cm', 'Descriptor': 'Linnaeus', 'Año': '1758', 'Sociabilidad': 'solitario'} ...

# %%
lista_tiburones
# Out:
# [{'Nombre_cientifico': 'Alopias pelagicus',
#   'Familia': 'alopiidae',
#   'Genero': 'Alopias',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '276 cm',
#   'Descriptor': 'Nakamura',
#   'Año': '1935',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Atelomycterus marmoratus',
#   'Familia': 'Scyliorhinidae',
#   'Genero': 'Atelomycterus',
#   'Status_IUCN': 'NT',
#   'Tamaño_medio': '55 cm',
#   'Descriptor': 'Bennet',
#   'Año': '1830',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Carcharhinus amblyrhynchos',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Carcharhinus',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '170 cm',
#   'Descriptor': 'Bleeker',
#   'Año': '1856',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Carcharhinus falciformis',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Carcharhinus',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '200 cm',
#   'Descriptor': 'Müller & Henle',
#   'Año': '1839',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Carcharhinus leucas',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Carcharhinus',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '190 cm',
#   'Descriptor': 'Müller & Henle',
#   'Año': '1839',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Carcharhinus melanopterus',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Carcharhinus',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '100 cm',
#   'Descriptor': 'Quoy & Gaimard',
#   'Año': '1824',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'carcharhinus plumbeus',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Carcharhinus',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '200 cm',
#   'Descriptor': 'Nardo',
#   'Año': '1827',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Carcharias taurus',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Carcharias',
#   'Status_IUCN': 'CR',
#   'Tamaño_medio': '220 cm',
#   'Descriptor': 'Rafinesque',
#   'Año': '1810',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Carcharodon carcharias',
#   'Familia': 'Lamnidae',
#   'Genero': 'Carcharodon',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '450 cm',
#   'Descriptor': 'Carl von Linné',
#   'Año': '1758',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Cetorhinus maximus',
#   'Familia': 'Cetorhinidae',
#   'Genero': 'Cetorhinus',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '1000 cm',
#   'Descriptor': 'Johan Ernst Gunnerus',
#   'Año': '1765',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Chiloscyllium griseum',
#   'Familia': 'Hemiscylliidae',
#   'Genero': 'Chiloscyllium',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '70 cm',
#   'Descriptor': 'Müller & Henle',
#   'Año': '1838',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Chiloscyllium punctatum',
#   'Familia': 'Hemiscylliidae',
#   'Genero': 'Chiloscyllium',
#   'Status_IUCN': 'NT',
#   'Tamaño_medio': '120 cm',
#   'Descriptor': 'Müller & Henle',
#   'Año': '1838',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Galeocerdo cuvier',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Galeocerdo',
#   'Status_IUCN': 'NT',
#   'Tamaño_medio': '300 cm',
#   'Descriptor': 'Péron & Le Sueur',
#   'Año': '1822',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Ginglymostoma cirratum',
#   'Familia': 'Ginglymostomatidae',
#   'Genero': 'Ginglymostoma',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '240 cm',
#   'Descriptor': 'Bonnaterre',
#   'Año': '1788',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Hemiscyllium Ocellatum',
#   'Familia': 'Hemiscylliidae',
#   'Genero': 'Hemiscyllium',
#   'Status_IUCN': 'LC',
#   'Tamaño_medio': '90 cm',
#   'Descriptor': 'Bonnaterre',
#   'Año': '1788',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Isurus oxyrinchus',
#   'Familia': 'Lamnidae',
#   'Genero': 'Isurus',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '270 cm',
#   'Descriptor': 'Rafinesque',
#   'Año': '1810',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Mustelus mosis',
#   'Familia': 'Triakidae',
#   'Genero': 'Mustelus',
#   'Status_IUCN': 'NT',
#   'Tamaño_medio': '100 cm',
#   'Descriptor': 'Hemprich & Ehrenberg',
#   'Año': '1899',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Mustelus mustelus',
#   'Familia': 'Triakidae',
#   'Genero': 'Mustelus',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '100 cm',
#   'Descriptor': 'Linnaeus',
#   'Año': '1758',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Negaprion brevirostris',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Negaprion',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '240 cm',
#   'Descriptor': 'Poey',
#   'Año': '1868',
#   'Sociabilidad': 'pequeños grupos'},
#  {'Nombre_cientifico': 'Orectolobus hutchinsi',
#   'Familia': 'Orectolobidae',
#   'Genero': 'Orectolobus',
#   'Status_IUCN': 'LC',
#   'Tamaño_medio': '240 cm',
#   'Descriptor': 'Last, Chidlow & Compagno',
#   'Año': '2006',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Poroderma africanum',
#   'Familia': 'Scyliorhinidae',
#   'Genero': 'Poroderma',
#   'Status_IUCN': 'LC',
#   'Tamaño_medio': '93 cm',
#   'Descriptor': 'Gmelin',
#   'Año': '1789',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Prionace glauca',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Prionace',
#   'Status_IUCN': 'NT',
#   'Tamaño_medio': '335 cm',
#   'Descriptor': 'Linnaeus',
#   'Año': '1758',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Pseudoginglymostoma brevicaudatum',
#   'Familia': 'Ginglymostomatidae',
#   'Genero': 'Pseudoginglymostoma',
#   'Status_IUCN': 'CR',
#   'Tamaño_medio': '60 cm',
#   'Descriptor': 'Günther',
#   'Año': '1867',
#   'Sociabilidad': 'solitario'},
#  {'Nombre_cientifico': 'Rhincodon typus',
#   'Familia': 'Rhincodontidae',
#   'Genero': 'Rhincodon',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '1000 cm',
#   'Descriptor': 'Smith',
#   'Año': '1828',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Scyliorhinus canicula',
#   'Familia': 'Scyliorhinidae',
#   'Genero': 'Scyliorhinus',
#   'Status_IUCN': 'LC',
#   'Tamaño_medio': '60 cm',
#   'Descriptor': 'Linnaeus',
#   'Año': '1758',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Scyliorhinus stellaris',
#   'Familia': 'Scyliorhinidae',
#   'Genero': 'Scyliorhinus',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '100 cm',
#   'Descriptor': 'Linnaeus',
#   'Año': '1758',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Sphyrna lewini',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Sphyrna',
#   'Status_IUCN': 'CR',
#   'Tamaño_medio': '300 cm',
#   'Descriptor': 'Griffith & Smith',
#   'Año': '1834',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Sphyrna mokarran',
#   'Familia': 'Carcharhinidae',
#   'Genero': 'Sphyrna',
#   'Status_IUCN': 'CR',
#   'Tamaño_medio': '300 cm',
#   'Descriptor': 'Rüppell',
#   'Año': '1837',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Squatina albipunctata',
#   'Familia': 'Squatinidae',
#   'Genero': 'Squatina',
#   'Status_IUCN': 'VU',
#   'Tamaño_medio': '100 cm',
#   'Descriptor': 'Last &White',
#   'Año': '2008',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Squatina squatina',
#   'Familia': 'Squatinidae',
#   'Genero': 'Squatina',
#   'Status_IUCN': 'CR',
#   'Tamaño_medio': '150 cm',
#   'Descriptor': 'Linnaeus',
#   'Año': '1758',
#   'Sociabilidad': 'grupos o en solitario'},
#  {'Nombre_cientifico': 'Stegostoma tigrinum',
#   'Familia': 'Stegostomatidae',
#   'Genero': 'Stegostoma',
#   'Status_IUCN': 'EN',
#   'Tamaño_medio': '250 cm',
#   'Descriptor': 'Forster',
#   'Año': '1781',
#   'Sociabilidad': 'grupos o en solitario'}]

# %%
df = pd.DataFrame(lista_tiburones)
df
# Out:
#                     Nombre_cientifico             Familia  \
# 0                   Alopias pelagicus           alopiidae
# 1            Atelomycterus marmoratus      Scyliorhinidae
# 2          Carcharhinus amblyrhynchos      Carcharhinidae
# 3            Carcharhinus falciformis      Carcharhinidae
# 4                 Carcharhinus leucas      Carcharhinidae
# 5           Carcharhinus melanopterus      Carcharhinidae
# 6               carcharhinus plumbeus      Carcharhinidae
# 7                   Carcharias taurus      Carcharhinidae
# 8              Carcharodon carcharias            Lamnidae
# 9                  Cetorhinus maximus        Cetorhinidae
# 10              Chiloscyllium griseum      Hemiscylliidae
# 11            Chiloscyllium punctatum      Hemiscylliidae
# 12                  Galeocerdo cuvier      Carcharhinidae
# 13             Ginglymostoma cirratum  Ginglymostomatidae
# 14             Hemiscyllium Ocellatum      Hemiscylliidae
# 15                  Isurus oxyrinchus            Lamnidae
# 16                     Mustelus mosis           Triakidae
# 17                  Mustelus mustelus           Triakidae
# 18             Negaprion brevirostris      Carcharhinidae
# 19              Orectolobus hutchinsi       Orectolobidae
# 20                Poroderma africanum      Scyliorhinidae
# 21                    Prionace glauca      Carcharhinidae
# 22  Pseudoginglymostoma brevicaudatum  Ginglymostomatidae
# 23                    Rhincodon typus      Rhincodontidae
# 24              Scyliorhinus canicula      Scyliorhinidae
# 25             Scyliorhinus stellaris      Scyliorhinidae
# 26                     Sphyrna lewini      Carcharhinidae
# 27                   Sphyrna mokarran      Carcharhinidae
# 28              Squatina albipunctata         Squatinidae
# 29                  Squatina squatina         Squatinidae
# 30                Stegostoma tigrinum     Stegostomatidae
#
#                  Genero Status_IUCN Tamaño_medio                Descriptor  \
# 0               Alopias          EN       276 cm                  Nakamura
# 1         Atelomycterus          NT        55 cm                    Bennet
# 2          Carcharhinus          EN       170 cm                   Bleeker
# 3          Carcharhinus          VU       200 cm            Müller & Henle
# 4          Carcharhinus          VU       190 cm            Müller & Henle
# 5          Carcharhinus          VU       100 cm            Quoy & Gaimard
# 6          Carcharhinus          EN       200 cm                     Nardo
# 7            Carcharias          CR       220 cm                Rafinesque
# 8           Carcharodon          VU       450 cm            Carl von Linné
# 9            Cetorhinus          EN      1000 cm      Johan Ernst Gunnerus
# 10        Chiloscyllium          VU        70 cm            Müller & Henle
# 11        Chiloscyllium          NT       120 cm            Müller & Henle
# 12           Galeocerdo          NT       300 cm          Péron & Le Sueur
# 13        Ginglymostoma          VU       240 cm                Bonnaterre
# 14         Hemiscyllium          LC        90 cm                Bonnaterre
# 15               Isurus          EN       270 cm                Rafinesque
# 16             Mustelus          NT       100 cm      Hemprich & Ehrenberg
# 17             Mustelus          EN       100 cm                  Linnaeus
# 18            Negaprion          VU       240 cm                      Poey
# 19          Orectolobus          LC       240 cm  Last, Chidlow & Compagno
# 20            Poroderma          LC        93 cm                    Gmelin
# 21             Prionace          NT       335 cm                  Linnaeus
# 22  Pseudoginglymostoma          CR        60 cm                   Günther
# 23            Rhincodon          EN      1000 cm                     Smith
# 24         Scyliorhinus          LC        60 cm                  Linnaeus
# 25         Scyliorhinus          VU       100 cm                  Linnaeus
# 26              Sphyrna          CR       300 cm          Griffith & Smith
# 27              Sphyrna          CR       300 cm                   Rüppell
# 28             Squatina          VU       100 cm               Last &White
# 29             Squatina          CR       150 cm                  Linnaeus
# 30           Stegostoma          EN       250 cm                   Forster
#
#      Año           Sociabilidad
# 0   1935              solitario
# 1   1830              solitario
# 2   1856              solitario
# 3   1839              solitario
# 4   1839              solitario
# 5   1824              solitario
# 6   1827              solitario
# 7   1810              solitario
# 8   1758              solitario
# 9   1765  grupos o en solitario
# 10  1838              solitario
# 11  1838              solitario
# 12  1822              solitario
# 13  1788              solitario
# 14  1788              solitario
# 15  1810              solitario
# 16  1899              solitario
# 17  1758              solitario
# 18  1868        pequeños grupos
# 19  2006              solitario
# 20  1789              solitario
# 21  1758              solitario
# 22  1867              solitario
# 23  1828  grupos o en solitario
# 24  1758  grupos o en solitario
# 25  1758  grupos o en solitario
# 26  1834  grupos o en solitario
# 27  1837  grupos o en solitario
# 28  2008  grupos o en solitario
# 29  1758  grupos o en solitario
# 30  1781  grupos o en solitario

# %%
df["Tamaño_medio"] = df["Tamaño_medio"].str.replace("cm","") #Limpieza de cm en Tamaño_medio

# %%
df
# Out:
#                     Nombre_cientifico             Familia  \
# 0                   Alopias pelagicus           alopiidae
# 1            Atelomycterus marmoratus      Scyliorhinidae
# 2          Carcharhinus amblyrhynchos      Carcharhinidae
# 3            Carcharhinus falciformis      Carcharhinidae
# 4                 Carcharhinus leucas      Carcharhinidae
# 5           Carcharhinus melanopterus      Carcharhinidae
# 6               carcharhinus plumbeus      Carcharhinidae
# 7                   Carcharias taurus      Carcharhinidae
# 8              Carcharodon carcharias            Lamnidae
# 9                  Cetorhinus maximus        Cetorhinidae
# 10              Chiloscyllium griseum      Hemiscylliidae
# 11            Chiloscyllium punctatum      Hemiscylliidae
# 12                  Galeocerdo cuvier      Carcharhinidae
# 13             Ginglymostoma cirratum  Ginglymostomatidae
# 14             Hemiscyllium Ocellatum      Hemiscylliidae
# 15                  Isurus oxyrinchus            Lamnidae
# 16                     Mustelus mosis           Triakidae
# 17                  Mustelus mustelus           Triakidae
# 18             Negaprion brevirostris      Carcharhinidae
# 19              Orectolobus hutchinsi       Orectolobidae
# 20                Poroderma africanum      Scyliorhinidae
# 21                    Prionace glauca      Carcharhinidae
# 22  Pseudoginglymostoma brevicaudatum  Ginglymostomatidae
# 23                    Rhincodon typus      Rhincodontidae
# 24              Scyliorhinus canicula      Scyliorhinidae
# 25             Scyliorhinus stellaris      Scyliorhinidae
# 26                     Sphyrna lewini      Carcharhinidae
# 27                   Sphyrna mokarran      Carcharhinidae
# 28              Squatina albipunctata         Squatinidae
# 29                  Squatina squatina         Squatinidae
# 30                Stegostoma tigrinum     Stegostomatidae
#
#                  Genero Status_IUCN Tamaño_medio                Descriptor  \
# 0               Alopias          EN         276                   Nakamura
# 1         Atelomycterus          NT          55                     Bennet
# 2          Carcharhinus          EN         170                    Bleeker
# 3          Carcharhinus          VU         200             Müller & Henle
# 4          Carcharhinus          VU         190             Müller & Henle
# 5          Carcharhinus          VU         100             Quoy & Gaimard
# 6          Carcharhinus          EN         200                      Nardo
# 7            Carcharias          CR         220                 Rafinesque
# 8           Carcharodon          VU         450             Carl von Linné
# 9            Cetorhinus          EN        1000       Johan Ernst Gunnerus
# 10        Chiloscyllium          VU          70             Müller & Henle
# 11        Chiloscyllium          NT         120             Müller & Henle
# 12           Galeocerdo          NT         300           Péron & Le Sueur
# 13        Ginglymostoma          VU         240                 Bonnaterre
# 14         Hemiscyllium          LC          90                 Bonnaterre
# 15               Isurus          EN         270                 Rafinesque
# 16             Mustelus          NT         100       Hemprich & Ehrenberg
# 17             Mustelus          EN         100                   Linnaeus
# 18            Negaprion          VU         240                       Poey
# 19          Orectolobus          LC         240   Last, Chidlow & Compagno
# 20            Poroderma          LC          93                     Gmelin
# 21             Prionace          NT         335                   Linnaeus
# 22  Pseudoginglymostoma          CR          60                    Günther
# 23            Rhincodon          EN        1000                      Smith
# 24         Scyliorhinus          LC          60                   Linnaeus
# 25         Scyliorhinus          VU         100                   Linnaeus
# 26              Sphyrna          CR         300           Griffith & Smith
# 27              Sphyrna          CR         300                    Rüppell
# 28             Squatina          VU         100                Last &White
# 29             Squatina          CR         150                   Linnaeus
# 30           Stegostoma          EN         250                    Forster
#
#      Año           Sociabilidad
# 0   1935              solitario
# 1   1830              solitario
# 2   1856              solitario
# 3   1839              solitario
# 4   1839              solitario
# 5   1824              solitario
# 6   1827              solitario
# 7   1810              solitario
# 8   1758              solitario
# 9   1765  grupos o en solitario
# 10  1838              solitario
# 11  1838              solitario
# 12  1822              solitario
# 13  1788              solitario
# 14  1788              solitario
# 15  1810              solitario
# 16  1899              solitario
# 17  1758              solitario
# 18  1868        pequeños grupos
# 19  2006              solitario
# 20  1789              solitario
# 21  1758              solitario
# 22  1867              solitario
# 23  1828  grupos o en solitario
# 24  1758  grupos o en solitario
# 25  1758  grupos o en solitario
# 26  1834  grupos o en solitario
# 27  1837  grupos o en solitario
# 28  2008  grupos o en solitario
# 29  1758  grupos o en solitario
# 30  1781  grupos o en solitario

# %%
lista_buena= df.values.tolist()

# %%
lista_de_tuplas = [tuple(sublista) for sublista in lista_buena]

print(lista_de_tuplas) #la lista de TUPLAS, que me admite SQL
# Out:
# [('Alopias pelagicus', 'alopiidae', 'Alopias', 'EN', '276 ', 'Nakamura', '1935', 'solitario'), ('Atelomycterus marmoratus', 'Scyliorhinidae', 'Atelomycterus', 'NT', '55 ', 'Bennet', '1830', 'solitario'), ('Carcharhinus amblyrhynchos', 'Carcharhinidae', 'Carcharhinus', 'EN', '170 ', 'Bleeker', '1856', 'solitario'), ('Carcharhinus falciformis', 'Carcharhinidae', 'Carcharhinus', 'VU', '200 ', 'Müller & Henle', '1839', 'solitario'), ('Carcharhinus leucas', 'Carcharhinidae', 'Carcharhinus', 'VU', '190 ', 'Müller & Henle', '1839', 'solitario'), ('Carcharhinus melanopterus', 'Carcharhinidae', 'Carcharhinus', 'VU', '100 ', 'Quoy & Gaimard', '1824', 'solitario'), ('carcharhinus plumbeus', 'Carcharhinidae', 'Carcharhinus', 'EN', '200 ', 'Nardo', '1827', 'solitario'), ('Carcharias taurus', 'Carcharhinidae', 'Carcharias', 'CR', '220 ', 'Rafinesque', '1810', 'solitario'), ('Carcharodon carcharias', 'Lamnidae', 'Carcharodon', 'VU', '450 ', 'Carl von Linné', '1758', 'solitario'), ('Cetorhinus maximus', 'Cetorhinidae', 'Cetorhinus', 'EN', '1000 ', 'Johan Ernst Gunnerus', '1765', 'grupos o en solitario'), ('Chiloscyllium griseum', 'Hemiscylliidae', 'Chiloscyllium', 'VU', '70 ', 'Müller & Henle', '1838', 'solitario'), ('Chiloscyllium punctatum', 'Hemiscylliidae', 'Chiloscyllium', 'NT', '120 ', 'Müller & Henle', '1838', 'solitario'), ('Galeocerdo cuvier', 'Carcharhinidae', 'Galeocerdo', 'NT', '300 ', 'Péron & Le Sueur', '1822', 'solitario'), ('Ginglymostoma cirratum', 'Ginglymostomatidae', 'Ginglymostoma', 'VU', '240 ', 'Bonnaterre', '1788', 'solitario'), ('Hemiscyllium Ocellatum', 'Hemiscylliidae', 'Hemiscyllium', 'LC', '90 ', 'Bonnaterre', '1788', 'solitario'), ('Isurus oxyrinchus', 'Lamnidae', 'Isurus', 'EN', '270 ', 'Rafinesque', '1810', 'solitario'), ('Mustelus mosis', 'Triakidae', 'Mustelus', 'NT', '100 ', 'Hemprich & Ehrenberg', '1899', 'solitario'), ('Mustelus mustelus', 'Triakidae', 'Mustelus', 'EN', '100 ', 'Linnaeus', '1758', 'solitario'), ('Negaprion brevirostris', 'Carcharhinidae', 'Negaprion', 'VU', '240 ', 'Poey', '1868', 'pequeños grupos'), ('Orectolobus hutchinsi', 'Orectolobidae', 'Orectolobus', 'LC', '240 ', 'Last, Chidlow & Compagno', '2006', 'solitario'), ('Poroderma africanum', 'Scyliorhinidae', 'Poroderma', 'LC', '93 ', 'Gmelin', '1789', 'solitario'), ('Prionace glauca', 'Carcharhinidae', 'Prionace', 'NT', '335 ', 'Linnaeus', '1758', 'solitario'), ('Pseudoginglymostoma brevicaudatum', 'Ginglymostomatidae', 'Pseudoginglymostoma', 'CR', '60 ', 'Günther', '1867', 'solitario'), ('Rhincodon typus', 'Rhincodontidae', 'Rhincodon', 'EN', '1000 ', 'Smith', '1828', 'grupos o en solitario'), ('Scyliorhinus canicula', 'Scyliorhinidae', 'Scyliorhinus', 'LC', '60 ', 'Linnaeus', '1758', 'grupos o en solitario'), ('Scyliorhinus stellaris', 'Scyliorhinidae', 'Scyliorhinus', 'VU', '100 ', 'Linnaeus', '1758', 'grupos o en solitario'), ('Sphyrna lewini', 'Carcharhinidae', 'Sphyrna', 'CR', '300 ', 'Griffith & Smith', '1834', 'grupos o en solitario'), ('Sphyrna mokarran', 'Carcharhinidae', 'Sphyrna', 'CR', '300 ', 'Rüppell', '1837', 'grupos o en solitario'), ('Squatina albipunctata', 'Squatinidae', 'Squatina', 'VU', '100 ', 'Last &White', '2008', 'grupos o en solitario'), ('Squatina squatina', 'Squatinidae', 'Squatina', 'CR', '150 ', 'Linnaeus', '1758', 'grupos o en solitario'), ('Stegostoma tigrinum', 'Stegostomatidae', 'Stegostoma', 'EN', '250 ', 'Forster', '1781', 'grupos o en solitario')]

# %%
# pip install --upgrade mysql-connector-python

# %%
# Para cargar un data en mysql

import mysql.connector
from mysql.connector import errorcode

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', #carretera de unión
                              host='127.0.0.1',
                              database ='tiburones',auth_plugin='mysql_native_password')

mycursor = cnx.cursor() # creamos el "camioncito que transporta"

# %%
query = """
INSERT INTO tiburones (Nombre_cientifico,Familia,Genero,Status_IUCN,Tamaño_medio,Descriptor,Año,Sociabilidad)
VALUES (%s, %s,%s,%s,%s,%s,%s,%s)
"""

# %%
# Insertar múltiples registros utilizando ejecutemany()
mycursor.executemany(query,lista_de_tuplas)

# Confirmar los cambios en la base de datos
cnx.commit()

print("Datos insertados correctamente ✅.")
print(mycursor.rowcount, "registros insertados")
# Out:
# Datos insertados correctamente ✅.
# 31 registros insertados

# %% [markdown]
# ✨Next steps✨
# - Añadir nuevas tablas para establecer nexos de unión (como nombre cientígico como PK) para ampliar la información y profundizar en nuestro análisis.
# - Coordenadas de avistamientos de las especies analizadas, y posible representación cartográfica con apoyo de QGIS.
