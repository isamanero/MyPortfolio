# %% [markdown]
# # Procesos de unión CSV --> Para gestión conjunta 🙌🏻

# %% [markdown]
# ## Importación de librerías y datos 📁

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %%
df_marine = pd.read_csv("../files/transition_files/Marine_microplastics/01_Marine_Microplastics_all_columns_EDA.csv")
df_marine.head()
# Out:
#    OBJECTID          Oceans               Regions  Sampling Method  \
# 0      9676  Atlantic Ocean  south atlantic ocean      Grab sample
# 1      6427   Pacific Ocean   north pacific ocean      Neuston net
# 2     10672   Pacific Ocean   north pacific ocean        Manta net
# 3     13921  Atlantic Ocean  north atlantic ocean  Aluminum bucket
# 4      9344   Pacific Ocean   north pacific ocean      Grab sample
#
#    Measurement       Unit Density Range Density Class       Short Reference  \
# 0        0.018  pieces/m3       0.005-1        Medium    Barrows et al.2018
# 1        0.000  pieces/m3      0-0.0005      Very Low        Law et al.2014
# 2        0.013  pieces/m3       0.005-1        Medium  Goldstein et al.2013
# 3     1368.000  pieces/m3            10     Very High    Queiroz et al.2022
# 4        0.001  pieces/m3  0.0005-0.005           Low    Barrows et al.2018
#
#                                       Long Reference  \
# 0  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 1  Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 2  Goldstein, M.C., A.J. Titmus, M. Ford. 2013. S...
# 3  Queiroz, A.F.dos S., A.S. da Conceição, D. Che...
# 4  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
#
#                                                DOI  \
# 0     https://doi.org/10.1016/j.envpol.2018.02.062
# 1                https://doi.org/10.1021/es4053076
# 2     https://doi.org/10.1371/journal.pone.0080020
# 3  https://doi.org/10.1016/j.scitotenv.2022.156259
# 4     https://doi.org/10.1016/j.envpol.2018.02.062
#
#                                         Organization  \
# 0                                Adventure Scientist
# 1                          Sea Education Association
# 2  Scripps Institution of Oceanography-University...
# 3                 Federal University of Pará, Brazil
# 4                                Adventure Scientist
#
#                               Keywords  Accession Number  \
# 0  Adventure Scientist/Citizen Science            211009
# 1                                  SEA            211008
# 2  Great Pacific Garbage Patch/SEAPLEX            253448
# 3             Amazon Continental Shelf            276482
# 4  Adventure Scientist/Citizen Science            211009
#
#                                       Accession Link   Latitude   Longitude  \
# 0  https://www.ncei.noaa.gov/access/metadata/land... -31.696000  -48.560000
# 1  https://www.ncei.noaa.gov/access/metadata/land...   6.350000 -121.850000
# 2  https://www.ncei.noaa.gov/access/metadata/land...   0.500000  -95.350000
# 3  https://www.ncei.noaa.gov/access/metadata/land...   0.631825  -45.398158
# 4  https://www.ncei.noaa.gov/access/metadata/land...  16.623000  -99.697800
#
#                      Date                              GlobalID  \
# 0   8/11/2015 12:00:00 AM  a77121b2-e113-444e-82d9-7af11d62fdd2
# 1  12/18/2002 12:00:00 AM  be27c450-02ca-4261-8d89-cae21108e6cc
# 2  10/17/2006 12:00:00 AM  23effcdd-35b7-4e1e-adb4-390693a287d3
# 3  10/17/2018 12:00:00 AM  16d77822-0533-4116-97b9-0bdb592f3d6e
# 4    1/3/2015 12:00:00 AM  b9e435e3-9e86-4143-8b51-877e5dcdc7a6
#
#    Density_Center
# 0         0.50250
# 1         0.00025
# 2         0.50250
# 3        10.00000
# 4         0.00275

# %% [markdown]
# ## Modificaciones previas ⚙️

# %%
# Vamos a crear la columna Location

df_marine['Location']=None

# %%
df_marine.shape
# Out:
# (20425, 21)

# %%
# Rellenamos [Location] con las Regiones:

# Localizaciones: Red Sea, Great Barrier Reef, Caribbean Sea, Galápagos, South China Sea, Maldives,Hawaiian Islands

# Red Sea: Red Sea
# Caribbean Sea:
# Maldives:
# Hawaiian Islands:
# Great Barrier Reef, South China Sea, y Galápagos (EN LOS OTROS CSV)

# %%
region_to_location = {
    "red sea":"red sea",
    "caribbean sea":[
"gulf of mexico",
"coastal waters of florida",
"florida keys national marine sanctuary",
"new york bight",
"gulf of st. lawrence",
"stellwagen bank national marine sanctuary",
"greater farallones national marine sanctuary",
"channel islands national marine sanctuary",
"monterey bay National marine sanctuary",
"gulf of california","caribbean sea"],
"galápagos":"south pacific ocean",
"maldives":"indian ocean",
"hawaiian islands":
["papahānaumokuākea marine national monument",
"hawaiian islands humpback whale national marine sanctuary"]}

# %%
# Creamos un nuevo diccionario vacío
region_to_location_expanded = {}

# Recorremos el diccionario original SIN modificarlo
for main_location, regions in region_to_location.items():
    if isinstance(regions, list):  # Si es una lista
        for r in regions:
            region_to_location_expanded[r.lower()] = main_location
    else:  # Si es solo un string
        region_to_location_expanded[regions.lower()] = main_location

# Ahora ya podemos mapear en el DataFrame
df_marine['Location'] = df_marine['Regions'].str.lower().map(region_to_location_expanded).fillna('Other')

# %%
df_marine['Location'].unique()
# Out:
# array(['Other', 'caribbean sea', 'galápagos', 'maldives', 'red sea',
#        'hawaiian islands'], dtype=object)

# %%
df_marine = df_marine.rename(columns={'Measurement': 'Microplastics Measurement (density)'})

# %%
df_marine = df_marine.rename(columns={'Density Class':'Concentration Class'})

# %%
# Separar la columna 'Date' en fecha y hora por el espacio
# En caso de que alguna fila no tenga espacio, la función llenará con NaN
df_marine[['Date_Only', 'Time_Only']] = df_marine['Date'].str.split(' ', expand=True, n=1)

# Verificar el resultado
print(df_marine[['Date_Only', 'Time_Only']].head())
# Out:
#     Date_Only    Time_Only
# 0   8/11/2015  12:00:00 AM
# 1  12/18/2002  12:00:00 AM
# 2  10/17/2006  12:00:00 AM
# 3  10/17/2018  12:00:00 AM
# 4    1/3/2015  12:00:00 AM

# %%
df_marine = df_marine.drop(columns=["Time_Only", "Date"])

# %%
df_marine
# Out:
#        OBJECTID          Oceans               Regions  Sampling Method  \
# 0          9676  Atlantic Ocean  south atlantic ocean      Grab sample
# 1          6427   Pacific Ocean   north pacific ocean      Neuston net
# 2         10672   Pacific Ocean   north pacific ocean        Manta net
# 3         13921  Atlantic Ocean  north atlantic ocean  Aluminum bucket
# 4          9344   Pacific Ocean   north pacific ocean      Grab sample
# ...         ...             ...                   ...              ...
# 20420      9366  Atlantic Ocean  north atlantic ocean      Grab sample
# 20421      4683  Atlantic Ocean         caribbean sea      Neuston net
# 20422      6043  Atlantic Ocean  north atlantic ocean      Neuston net
# 20423     20169  Atlantic Ocean  north atlantic ocean     Hand picking
# 20424     10726  Atlantic Ocean     mediterranean sea        Manta net
#
#        Microplastics Measurement (density)            Unit Density Range  \
# 0                                   0.0180       pieces/m3       0.005-1
# 1                                   0.0000       pieces/m3      0-0.0005
# 2                                   0.0130       pieces/m3       0.005-1
# 3                                1368.0000       pieces/m3            10
# 4                                   0.0010       pieces/m3  0.0005-0.005
# ...                                    ...             ...           ...
# 20420                               0.0110       pieces/m3       0.005-1
# 20421                               0.0216       pieces/m3       0.005-1
# 20422                               0.0000       pieces/m3      0-0.0005
# 20423                                  NaN  pieces/10 mins        40-200
# 20424                               0.3260       pieces/m3       0.005-1
#
#       Concentration Class       Short Reference  \
# 0                  Medium    Barrows et al.2018
# 1                Very Low        Law et al.2014
# 2                  Medium  Goldstein et al.2013
# 3               Very High    Queiroz et al.2022
# 4                     Low    Barrows et al.2018
# ...                   ...                   ...
# 20420              Medium    Barrows et al.2018
# 20421              Medium        Law et al.2010
# 20422            Very Low        Law et al.2010
# 20423                High   Tunnell et al. 2020
# 20424              Medium    de Haan et al.2022
#
#                                           Long Reference  ...  \
# 0      Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...  ...
# 1      Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...  ...
# 2      Goldstein, M.C., A.J. Titmus, M. Ford. 2013. S...  ...
# 3      Queiroz, A.F.dos S., A.S. da Conceição, D. Che...  ...
# 4      Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...  ...
# ...                                                  ...  ...
# 20420  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...  ...
# 20421  Law, K.L., S. Morét-Ferguson, N.A. Maximenko, ...  ...
# 20422  Law, K.L., S. Morét-Ferguson, N.A. Maximenko, ...  ...
# 20423  Tunnell, Jace W.; Dunning, Kelly H.; Scheef, L...  ...
# 20424  de Haan, W.P., O. Uviedo, M. Ballesteros, I. C...  ...
#
#                                             Organization  \
# 0                                    Adventure Scientist
# 1                              Sea Education Association
# 2      Scripps Institution of Oceanography-University...
# 3                     Federal University of Pará, Brazil
# 4                                    Adventure Scientist
# ...                                                  ...
# 20420                                Adventure Scientist
# 20421                          Sea Education Association
# 20422                          Sea Education Association
# 20423       University of Texas Marine Science Institute
# 20424                            University of Barcelona
#
#                                   Keywords Accession Number  \
# 0      Adventure Scientist/Citizen Science           211009
# 1                                      SEA           211008
# 2      Great Pacific Garbage Patch/SEAPLEX           253448
# 3                 Amazon Continental Shelf           276482
# 4      Adventure Scientist/Citizen Science           211009
# ...                                    ...              ...
# 20420  Adventure Scientist/Citizen Science           211009
# 20421                                  SEA           211007
# 20422                                  SEA           211007
# 20423                        Nurdle Patrol           259486
# 20424   Citizen science; Surf board; Kayak           253923
#
#                                           Accession Link   Latitude  \
# 0      https://www.ncei.noaa.gov/access/metadata/land... -31.696000
# 1      https://www.ncei.noaa.gov/access/metadata/land...   6.350000
# 2      https://www.ncei.noaa.gov/access/metadata/land...   0.500000
# 3      https://www.ncei.noaa.gov/access/metadata/land...   0.631825
# 4      https://www.ncei.noaa.gov/access/metadata/land...  16.623000
# ...                                                  ...        ...
# 20420  https://www.ncei.noaa.gov/access/metadata/land...  17.100000
# 20421  https://www.ncei.noaa.gov/access/metadata/land...  21.390000
# 20422  https://www.ncei.noaa.gov/access/metadata/land...  24.140000
# 20423  https://www.ncei.noaa.gov/access/metadata/land...  39.924800
# 20424  https://www.ncei.noaa.gov/access/metadata/land...  40.910469
#
#         Longitude                              GlobalID Density_Center  \
# 0      -48.560000  a77121b2-e113-444e-82d9-7af11d62fdd2        0.50250
# 1     -121.850000  be27c450-02ca-4261-8d89-cae21108e6cc        0.00025
# 2      -95.350000  23effcdd-35b7-4e1e-adb4-390693a287d3        0.50250
# 3      -45.398158  16d77822-0533-4116-97b9-0bdb592f3d6e       10.00000
# 4      -99.697800  b9e435e3-9e86-4143-8b51-877e5dcdc7a6        0.00275
# ...           ...                                   ...            ...
# 20420  -47.550000  fd4db6d6-aed7-48b1-a22b-402557112e2f        0.50250
# 20421  -81.960000  83a8208e-2d06-4ad9-bcd9-81e29d57e0aa        0.50250
# 20422  -81.980000  0fd72d83-cd27-42e1-b63a-b015c23b28d2        0.00025
# 20423  -75.127200  fc84069e-c782-4c3d-bf6b-265535969d8e      120.00000
# 20424    0.833376  b840a79b-6d98-4def-ac53-5447be1531b9        0.50250
#
#             Location   Date_Only
# 0              Other   8/11/2015
# 1              Other  12/18/2002
# 2              Other  10/17/2006
# 3              Other  10/17/2018
# 4              Other    1/3/2015
# ...              ...         ...
# 20420          Other    2/1/2015
# 20421  caribbean sea   3/14/2001
# 20422          Other    5/1/2008
# 20423          Other  10/28/2021
# 20424          Other   3/11/2021
#
# [20425 rows x 21 columns]

# %%
df_marine = df_marine.rename(columns={'Date_Only': 'Date'})

# %%
#df_marine.to_csv('../files/transition_files/Marine_microplastics/01_Marine_Microplastics_all_columns_EDA.csv')

# %% [markdown]
# ## Unión de CSVs listos 👉🏻👈🏻

# %%
df1 = pd.read_csv("../files/transition_files/Microplastics_por_zonas/Galapagoscolum.csv")
df2 = pd.read_csv("../files/transition_files/Microplastics_por_zonas/Great_Barrier_Reefcolum.csv")
df3 = pd.read_csv("../files/transition_files/Microplastics_por_zonas/South_China_Seacolum.csv")
df4 = pd.read_csv("../files/transition_files/Marine_microplastics/01_Marine_Microplastics_all_columns_EDA.csv")

# %%
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()

# %%
df1=df1[['OBJECTID', 'Date', 'Latitude', 'Longitude', 'Oceans', 'Regions',
       'Location', 'Microplastics Measurement (density)', 'Unit',
       'Density Range', 'Concentration Class', 'Sampling Method',
       'Organization']]

df2=df2[['OBJECTID', 'Date', 'Latitude', 'Longitude', 'Oceans', 'Regions',
       'Location', 'Microplastics Measurement (density)', 'Unit',
       'Density Range', 'Concentration Class', 'Sampling Method',
       'Organization']]

df3=df3[['OBJECTID', 'Date', 'Latitude', 'Longitude', 'Oceans', 'Regions',
       'Location', 'Microplastics Measurement (density)', 'Unit',
       'Density Range', 'Concentration Class', 'Sampling Method',
       'Organization']]

df4=df4[['OBJECTID', 'Date', 'Latitude', 'Longitude', 'Oceans', 'Regions',
       'Location', 'Microplastics Measurement (density)', 'Unit',
       'Density Range', 'Concentration Class', 'Sampling Method',
       'Organization']]

# %%
df2.columns
# Out:
# Index(['OBJECTID', 'Date', 'Latitude', 'Longitude', 'Oceans', 'Regions',
#        'Location', 'Microplastics Measurement (density)', 'Unit',
#        'Density Range', 'Concentration Class', 'Sampling Method',
#        'Organization'],
#       dtype='object')

# %%
columnas_finales = df2.columns

# %%
df1 = df1.reindex(columns=columnas_finales)
df2 = df2.reindex(columns=columnas_finales)
df3 = df3.reindex(columns=columnas_finales)
df4 = df4.reindex(columns=columnas_finales)

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
# Out:
# (24, 13)
# (65, 13)
# (182, 13)
# (20425, 13)

# %%
combined_df = pd.concat ([df1,df2, df3, df4], ignore_index=True)

# %%
combined_df.to_csv('../files/transition_files/Marine_microplastics/02_Microplastic_marine_withLocation_Date.csv', index=False)

# %%
df_unido = pd.read_csv("../files/transition_files/Marine_microplastics/02_Microplastic_marine_withLocation_Date.csv", sep=",")

# %%
# Función para corregir el formato de fecha
def corregir_fecha(fecha):
    try:
        # Intentar convertir a formato DD/MM/YYYY
        fecha = pd.to_datetime(fecha, format='%d/%m/%Y', errors='raise')
    except:
        try:
            # Si no se puede, intentar convertir a formato MM/DD/YYYY
            fecha = pd.to_datetime(fecha, format='%m/%d/%Y', errors='raise')
            # Cambiar la fecha de formato MM/DD/YYYY a DD/MM/YYYY
            fecha = fecha.strftime('%d/%m/%Y')
        except:
            fecha = None  # Si no se puede convertir, asignar None
    return fecha

# Aplicar la corrección de fecha a la columna 'Date' de df_llorar
df_unido['Date'] = df_unido['Date'].apply(corregir_fecha)

# Verificar si algunas fechas siguen siendo nulas y ver el error
print(df_unido[df_unido['Date'].isnull()])

# Guardar el archivo CSV con las fechas corregidas (si necesitas guardarlo)
# df_unido.to_csv('files/clean_files/Marine_actualizado.csv', index=False)
# Out:
# Empty DataFrame
# Columns: [OBJECTID, Date, Latitude, Longitude, Oceans, Regions, Location, Microplastics Measurement (density), Unit, Density Range, Concentration Class, Sampling Method, Organization]
# Index: []

# %%
df_unido
# Out:
#        OBJECTID                 Date   Latitude  Longitude          Oceans  \
# 0          6191  2001-12-04 00:00:00     0.0700 -89.790000   Pacific Ocean
# 1          6192  2001-12-05 00:00:00    -0.5100 -90.080000   Pacific Ocean
# 2          6193  2001-12-08 00:00:00    -0.8700 -90.260000   Pacific Ocean
# 3          6194  2001-12-09 00:00:00      -1,21 -90.430000   Pacific Ocean
# 4          6195  2001-12-09 00:00:00      -1,07 -90.840000   Pacific Ocean
# ...         ...                  ...        ...        ...             ...
# 20691      9366  2015-01-02 00:00:00       17.1 -47.550000  Atlantic Ocean
# 20692      4683           14/03/2001      21.39 -81.960000  Atlantic Ocean
# 20693      6043  2008-01-05 00:00:00      24.14 -81.980000  Atlantic Ocean
# 20694     20169           28/10/2021    39.9248 -75.127200  Atlantic Ocean
# 20695     10726  2021-11-03 00:00:00  40.910469   0.833376  Atlantic Ocean
#
#                     Regions       Location  \
# 0                 Galápagos      Galápagos
# 1                 Galápagos      Galápagos
# 2                 Galápagos      Galápagos
# 3                 Galápagos      Galápagos
# 4                 Galápagos      Galápagos
# ...                     ...            ...
# 20691  north atlantic ocean          Other
# 20692         caribbean sea  caribbean sea
# 20693  north atlantic ocean          Other
# 20694  north atlantic ocean          Other
# 20695     mediterranean sea          Other
#
#       Microplastics Measurement (density)            Unit Density Range  \
# 0                                     0.0       pieces/m3      0-0.0005
# 1                                     0.0       pieces/m3      0-0.0005
# 2                                     0.0       pieces/m3      0-0.0005
# 3                                     0.0       pieces/m3      0-0.0005
# 4                                     0.0       pieces/m3      0-0.0005
# ...                                   ...             ...           ...
# 20691                               0.011       pieces/m3       0.005-1
# 20692                              0.0216       pieces/m3       0.005-1
# 20693                                 0.0       pieces/m3      0-0.0005
# 20694                                 NaN  pieces/10 mins        40-200
# 20695                               0.326       pieces/m3       0.005-1
#
#       Concentration Class Sampling Method  \
# 0                Very Low     Neuston net
# 1                Very Low     Neuston net
# 2                Very Low     Neuston net
# 3                Very Low     Neuston net
# 4                Very Low     Neuston net
# ...                   ...             ...
# 20691              Medium     Grab sample
# 20692              Medium     Neuston net
# 20693            Very Low     Neuston net
# 20694                High    Hand picking
# 20695              Medium       Manta net
#
#                                        Organization
# 0                         Sea Education Association
# 1                         Sea Education Association
# 2                         Sea Education Association
# 3                         Sea Education Association
# 4                         Sea Education Association
# ...                                             ...
# 20691                           Adventure Scientist
# 20692                     Sea Education Association
# 20693                     Sea Education Association
# 20694  University of Texas Marine Science Institute
# 20695                       University of Barcelona
#
# [20696 rows x 13 columns]

# %% [markdown]
# ## Unión final: 🌊+🪸

# %%
#Algunas modificaciones previas
df5 = pd.read_csv("../files/clean_files/realistic_ocean_climate_dataset.csv")

# %%
df5.columns
# Out:
# Index(['Date', 'Location', 'Latitude', 'Longitude', 'SST (°C)', 'pH Level',
#        'Bleaching Severity', 'Species Observed', 'Marine Heatwave'],
#       dtype='object')

# %%
df5 = df5.rename(columns={'Date': 'Date_coral'})

# %%
df5.columns
# Out:
# Index(['Date_coral', 'Location', 'Latitude', 'Longitude', 'SST (°C)',
#        'pH Level', 'Bleaching Severity', 'Species Observed',
#        'Marine Heatwave'],
#       dtype='object')

# %%
# Cargar los CSV
uni1 = pd.read_csv('../files/transition_files/Marine_microplastics/02_Microplastic_marine_withLocation_Date.csv')
uni2 = pd.read_csv("../files/clean_files/realistic_ocean_climate_dataset.csv")

# Limpiar 'Location': minúsculas y sin espacios extra
uni1['Location'] = uni1['Location'].str.strip().str.lower()
uni2['Location'] = uni2['Location'].str.strip().str.lower()

# Extraer año
uni1['Year'] = pd.to_datetime(uni1['Date'], errors='coerce').dt.year
uni2['Year'] = pd.to_datetime(uni2['Date'], errors='coerce').dt.year

# Hacer el LEFT JOIN usando uni2 como base
df_unido2 = pd.merge(uni2, uni1, on=['Location', 'Year'], how='left')

# Guardar el resultado
#df_unido2.to_csv('files/clean_files/arrecife_mas_info.csv', index=False)

# Mostrar un resumen
print(df_unido2.head())
# Out:
#        Date_x            Location  Latitude_x  Longitude_x  SST (°C)  \
# 0  2015-01-01             red sea     20.0248      38.4931     29.47
# 1  2015-01-07  great barrier reef    -18.2988     147.7782     29.65
# 2  2015-01-14       caribbean sea     14.9768     -75.0233     28.86
# 3  2015-01-14       caribbean sea     14.9768     -75.0233     28.86
# 4  2015-01-14       caribbean sea     14.9768     -75.0233     28.86
#
#    pH Level Bleaching Severity  Species Observed  Marine Heatwave  Year  ...  \
# 0     8.107                NaN               106            False  2015  ...
# 1     8.004               High               116            False  2015  ...
# 2     7.947               High                90            False  2015  ...
# 3     7.947               High                90            False  2015  ...
# 4     7.947               High                90            False  2015  ...
#
#    Latitude_y Longitude_y          Oceans               Regions  \
# 0         NaN         NaN             NaN                   NaN
# 1         NaN         NaN             NaN                   NaN
# 2   10.760339  -61.441728  Atlantic Ocean         caribbean sea
# 3     46.3883  -63.782500  Atlantic Ocean  gulf of st. lawrence
# 4       46.23  -63.145600  Atlantic Ocean  gulf of st. lawrence
#
#   Microplastics Measurement (density)       Unit Density Range  \
# 0                                 NaN        NaN           NaN
# 1                                 NaN        NaN           NaN
# 2                            0.666667  pieces/m3         0-100
# 3                               0.001  pieces/m3  0.0005-0.005
# 4                               0.001  pieces/m3  0.0005-0.005
#
#   Concentration Class Sampling Method  \
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2            Very Low    Hand picking
# 3                 Low     Grab sample
# 4                 Low     Grab sample
#
#                                         Organization
# 0                                                NaN
# 1                                                NaN
# 2  University of the West Indies, St. Augustine C...
# 3                                Adventure Scientist
# 4                                Adventure Scientist
#
# [5 rows x 22 columns]
