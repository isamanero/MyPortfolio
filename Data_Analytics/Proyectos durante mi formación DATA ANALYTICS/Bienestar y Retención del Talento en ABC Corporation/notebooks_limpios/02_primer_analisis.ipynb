# %%
import pandas as pd

df = pd.read_csv("../files/original_hr_raw_data.csv", index_col=0)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Primeros análisis del DF

# %%
df.head(10)
# Out:
#   age attrition     businesstravel    dailyrate                department  \
# 0  51        No                NaN  2015.722222                       NaN
# 1  52        No                NaN  2063.388889                       NaN
# 2  42        No      travel_rarely  1984.253968   Research & Development
# 3  47        No      travel_rarely  1771.404762                       NaN
# 4  46        No                NaN  1582.771346                       NaN
# 5  48        No                NaN  1771.920635   Research & Development
# 6  59        No                NaN  1032.487286                       NaN
# 7  42        No      travel_rarely   556.256661                       NaN
# 8  41        No                NaN  1712.182540                       NaN
# 9  41        No  travel_frequently  1973.984127                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# ...

# %%
df.shape
# Out:
# (1678, 41)

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...

# %% [markdown]
# object
#  1. age
#  2. attrition -> object
#  3. businesstravel -> object
#  4. dailyrate -> float64
#  5. department -> object
#  6. distancefromhome -> int64
#  7. education -> int64
#  8. educationfield -> object
#  9. employeecount -> int64
#  10. employeenumber -> int64
#  11. environmentsatisfaction -> int64
#  12. gender -> int64
#  13. hourlyrate -> float64
#  14. jobinvolvement -> int64
#  15. joblevel -> int64
#  16. jobrole -> object
#  17. jobsatisfaction -> int64
#  18. maritalstatus -> object
#  19. monthlyincome -> object
#  20. monthlyrate -> object
#  21. numcompaniesworked -> int64
#  22. over18 -> object
#  23. overtime -> object
#  24. percentsalaryhike -> int64
#  25. performancerating -> object
#  26. relationshipsatisfaction -> int64
#  27. standardhours -> object
#  28. stockoptionlevel -> int64
#  29. totalworkingyears -> object
#  30. trainingtimeslastyear -> int64
#  31. worklifebalance -> object
#  32. yearsatcompany -> int64
#  33. yearsincurrentrole -> object
#  34. yearssincelastpromotion -> int64
#  35. yearswithcurrmanager -> int64
#  36. sameasmonthlyincome -> object
#  37. datebirth -> int64
#  38. salary -> object
#  39. roledepartament -> object
#  40. numberchildren -> float64
#  41. remotework -> object

# %% [markdown]
# # Definición de las actuaciones por columnas

# %% [markdown]
# ## columnas que vamos a borrar
#
# 1.age: Hay datos en int y otros en str con guiones.
# CAMBIAR A TIPO INTEGER. CEO- RECALCULAR COLUMNA CON AÑO DE NACIMIENTO O BORRAR COLUMNA
#
# 9.Employeecount: valor único de 1. CAMBIAR: borrar:calavera:
#
# 22.over18: Y:yes y Nan :calavera:
#
# 33.yearsincurrentrole: todo NAN, parece inservible, es STRING:calavera:
#
# 36.sameasmonthlyincome: es STRING sale con dolar y coma, tiene que ser FLOAT :calavera: CEO - BORRAR COLUMNA
#
# 39.roledepartament: muchos NAN, hay un guion que habría que quitar y separar entre role y department, debería ser string. :calavera:
#
# 40.numberchildren: es FLOAT , no tiene sentido, no se puede tener un niño y medio, es todo NAN, se puede borrar

# %% [markdown]
# ## columnas a modificar
#
# 4.Dailyrate: float con muchos decimales. CEO - PARA EL ANALISIS,CON LA COLUMNA SALARIO ES SUFICIENTE
# CAMBIAR: Redondear a menos decimales. Mantener por el momento, no está claro si la necesitamos.
#
# 6.Distancefromhome: int con valores negativos.
# CAMBIAR: Por el momento la mantenemos, quizás innecesaria.
#
# 11.Enviromentsatisfaction: int (del 1 al 5 pero hay 35, 42 y 47?) CEO-ANALIZAR ESOS DATOS (RANGOS DE LOS DATOS)
#
# 12.Gender: int (0 y 1, a cambiar por 'Male' y 'Female') CEO - SIENDO 0 MALE Y 1 FEMALE
#
# 16.jobrole: str (Sales executive, Laboratory technician) (quizás poner todo en mayúsculas o minúsculas?)
#
# 25.performancerating: Mal el formato de float, usa "," cambiarlo por "." (lo saca como string)
#
# 29.totalworkingyears: Mal el formato de float, usa "," cambiarlo por "." (lo saca como string) "Podríamos redondear a años enteros y hacer un int"
#
# 31.worklifebalance: Mal el formato de float, usa "," cambiarlo por "." (string) habría que pasarlo a int
#
# 38.salary: es STRING sale con dolar y coma, tiene que ser FLOAT
#
# 41.remotework: STRING deberia ser solo Yes/No, pero sale tambien False/True y 1/0. CEO - 0 FALSE Y 1 TRUE
#
#
#
# ** Estas dos no estaban en el sitio correcto pero hay que modificar lo siguiente: **
#
# 19.monthlyincome: SALARIO str (cambiar a float, replace $, cambiar coma por punto y NaN por NULL)
# Esta hay que
# - pasar de STRING a Float,
# - cambiar la coma por el punto y
# - eliminar el $,
# - después también cambiar NaN por NULL
#
# 20.monthlyrate: TARIFA str (cambiar , replace $, cambiar coma por punto y NaN por NULL) CANDIDATA :calavera: . CEO - PARA EL ANALISIS, CON LA COLUMNA SALARIO ES SUFICIENTE
# Esta hay que
# - pasar de STRING a Float,
# - cambiar la coma por el punto y
# - eliminar el $,
# - no eliminar, aunque no es interesante para nosotras, el cliente puede necesitarla

# %% [markdown]
# ## columnas ok
#
# 2.Attrition: Valores YES/NO. Está ok
#
# 7.Education: int que va del 1 al 5.
#
# 10.Employeenumber: int
#
# 14.Jobinvolvement: int (del 1 al 4) rango ok
#
# 15.joblevel: int (del 1 al 5) rango ok
#
# 17.Jobsatisfaction: int del 1 al 4. VALIDADO POR EL CEO.
#
# 21.numcompaniesworked: int
#
# 23.overtime: No-Yes
#
# 24.percentsalaryhike: int, bien
#
# 26.relationshipsatisfaction: puntuacion 1-4 (in)
#
# 27.standardhours: Part Time y Full Time, no sé si nos dará
# problemas ese espacio.
#
# 28.stockoptionlevel: int (0-3) beneficios que se pueden obtener, que tiene que ver con las acciones
#
# 30.trainingtimeslastyear: int (0-6)
#
# 32.yearsatcompany: INT, todo ok
#
# 34.yearssincelastpromotion: INT, todo ok
#
# 35.yearswithcurrmanager: INT, todo ok
#
# 37.datebirth: INT años, todo ok

# %% [markdown]
# ## cambiar NaN por Null:
#
# 3.Businesstravel: travel_rarely/travel_frequently/NaN/non-travel.
#  CAMBIAR Nan por null. Demás OK
#
# 5.Department: NaN/Research & Development/Sales/Human Resources. CAMBIAR: cambiar Nan por Null y
# NO eliminar Department porque ya eliminamos "roleDepartment", aunque no nos aporte mucha info
#
# 8.Educationfield: NaN/Life Sciences/Technical Degree/Medical/Marketing/Human Resources/Other. Cambiar NaN por NULL
#
# 13.Hourlyrate(tarifa por hora): float (pero la mayoría NaN?) cambiar NaN por NULL (no borramos porque aunuqe es info que a nosotras no nos sirve, son datos que el cliente quizás si necesita)
#
# 18.Maritalstatus: str (Married, Divorced, Single, NaN) cambiar NaN por NULL, demás OK

# %% [markdown]
# # Filas duplicadas

# %%
df.duplicated(keep=False, subset="employeenumber").sum()
# Out:
# np.int64(128)

# %%
filas_dup= df[df.duplicated()].sort_values("employeenumber") #(keep=False)
filas_dup
# Out:
#               age attrition     businesstravel    dailyrate  \
# 1656           41        No                NaN  1712.182540
# 1652           36        No                NaN   610.174603
# 1676           47        No      travel_rarely  1032.487286
# 1649           29        No      travel_rarely  1032.487286
# 1616           30        No      travel_rarely  1032.487286
# 1617           34       Yes      travel_rarely   556.256661
# 1623           36        No      travel_rarely   556.256661
# 1614           35        No                NaN  1032.487286
# 1629           37        No                NaN  1032.487286
# 1644           50        No                NaN   290.035510
# 1624           31        No      travel_rarely   456.444444
# 1634           35        No                NaN  1032.487286
# 1630           47       Yes         non-travel  1032.487286
# 1642           26       Yes      travel_rarely   601.301587
# 1633           29        No                NaN   447.261905
# ...

# %% [markdown]
# # Porcentaje de nulos

# %%
round(df.isna().sum()/df.shape[0]*100, 2)
# Out:
# age                           0.00
# attrition                     0.00
# businesstravel               47.74
# dailyrate                     0.00
# department                   81.41
# distancefromhome              0.00
# education                     0.00
# educationfield               46.13
# employeecount                 0.00
# employeenumber                0.00
# environmentsatisfaction       0.00
# gender                        0.00
# hourlyrate                   75.51
# jobinvolvement                0.00
# joblevel                      0.00
# jobrole                       0.00
# jobsatisfaction               0.00
# maritalstatus                40.23
# monthlyincome                29.14
# monthlyrate                   0.00
# numcompaniesworked            0.00
# over18                       55.90
# overtime                     41.48
# percentsalaryhike             0.00
# performancerating            11.92
# relationshipsatisfaction      0.00
# standardhours                20.92
# ...
